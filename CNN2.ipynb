# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import cv2
import os
import numpy as np
import seaborn as sns 
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from tensorflow.keras.models import Sequential,load_model
from tensorflow.keras.layers import Conv2D,MaxPool2D,Flatten,Dense

# %%
data1=r"C:\Users\asus\Downloads\Deeplearningdataset\Dataset"

# %%
x1,y1=[],[]
for i in os.listdir(data1):
    new_dir=os.path.join(data1,i)
    if os.path.isdir(new_dir):
        for j in os.listdir(new_dir):
            image_path=os.path.join(new_dir,j)
            if image_path is not None:
                image_data=cv2.imread(image_path)
                array_resize=cv2.resize(image_data,(100,100))
                array_reshape=array_resize.reshape(100,100,3)
                array_norm=array_reshape/255
                x1.append(array_norm)
                y1.append(i)

# %%
x=np.array(x1)
y=np.array(y1)
print(x.shape)
print(y.shape)
# Out:
# (8982, 100, 100, 3)
# (8982,)

# %%
y
# Out:
# array(['mask_weared_incorrect', 'mask_weared_incorrect',
#        'mask_weared_incorrect', ..., 'with_mask', 'with_mask',
#        'with_mask'], dtype='<U21')

# %%
le=LabelEncoder()
y=le.fit_transform(y)
y
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=40)

# %%
model=Sequential()
model.add(Conv2D(32,(3,3),activation="relu",input_shape=(100,100,3)))
model.add(MaxPool2D(2,2))
model.add(Conv2D(64,(3,3),activation="relu"))
model.add(MaxPool2D(2,2))
model.add(Conv2D(128,(3,3),activation="relu"))
model.add(MaxPool2D(2,2))
model.add(Flatten())
model.add(Dense(128,activation="relu"))
model.add(Dense(3,activation="softmax"))

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 98, 98, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 49, 49, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 47, 47, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 23, 23, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 21, 21, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 10, 10, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 12800)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     1,638,528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │           387 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,732,163 (6.61 MB)
#  Trainable params: 1,732,163 (6.61 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam",loss="sparse_categorical_crossentropy",metrics=["accuracy"])

# %%
model.fit(xtrain,ytrain,batch_size=40,epochs=18,validation_data=(xtest,ytest))
# Out:
# Epoch 1/18
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 143s 827ms/step - accuracy: 0.8478 - loss: 0.3808 - val_accuracy: 0.9080 - val_loss: 0.2484
# Epoch 2/18
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 123s 707ms/step - accuracy: 0.9402 - loss: 0.1766 - val_accuracy: 0.9573 - val_loss: 0.1253
# Epoch 3/18
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 91s 573ms/step - accuracy: 0.9620 - loss: 0.1109 - val_accuracy: 0.9670 - val_loss: 0.1043
# Epoch 4/18
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 91s 577ms/step - accuracy: 0.9739 - loss: 0.0785 - val_accuracy: 0.9625 - val_loss: 0.1076
# Epoch 5/18
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 93s 589ms/step - accuracy: 0.9795 - loss: 0.0594 - val_accuracy: 0.9588 - val_loss: 0.1179
# Epoch 6/18
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 93s 587ms/step - accuracy: 0.9849 - loss: 0.0501 - val_accuracy: 0.9759 - val_loss: 0.0617
# Epoch 7/18
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 96s 605ms/step - accuracy: 0.9913 - loss: 0.0253 - val_accuracy: 0.9670 - val_loss: 0.1064
# Epoch 8/18
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 104s 659ms/step - accuracy: 0.9903 - loss: 0.0280 - val_accuracy: 0.9796 - val_loss: 0.0643
# Epoch 9/18
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 114s 721ms/step - accuracy: 0.9849 - loss: 0.0490 - val_accuracy: 0.9477 - val_loss: 0.1382
# Epoch 10/18
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 104s 659ms/step - accuracy: 0.9954 - loss: 0.0170 - val_accuracy: 0.9818 - val_loss: 0.0718
# Epoch 11/18
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 92s 581ms/step - accuracy: 0.9792 - loss: 0.0660 - val_accuracy: 0.9685 - val_loss: 0.0909
# Epoch 12/18
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 143s 583ms/step - accuracy: 0.9943 - loss: 0.0155 - val_accuracy: 0.9751 - val_loss: 0.0704
# Epoch 13/18
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 106s 668ms/step - accuracy: 0.9978 - loss: 0.0064 - val_accuracy: 0.9855 - val_loss: 0.0619
# Epoch 14/18
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 95s 599ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9889 - val_loss: 0.0486
# Epoch 15/18
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 100s 634ms/step - accuracy: 1.0000 - loss: 3.3634e-04 - val_accuracy: 0.9896 - val_loss: 0.0457
# Epoch 16/18
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 110s 428ms/step - accuracy: 1.0000 - loss: 1.5611e-04 - val_accuracy: 0.9892 - val_loss: 0.0465
# Epoch 17/18
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 42s 267ms/step - accuracy: 1.0000 - loss: 1.0789e-04 - val_accuracy: 0.9892 - val_loss: 0.0473
# Epoch 18/18
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 96s 608ms/step - accuracy: 1.0000 - loss: 8.7690e-05 - val_accuracy: 0.9889 - val_loss: 0.0466

# %%
test_data1=r"C:\Users\asus\Downloads\Deeplearningdataset\Dataset\with_mask\98.png"

# %%
image_data1=cv2.imread(test_data1)
array_resize=cv2.resize(image_data1,(100,100))
array_reshape=array_resize.reshape(1,100,100,3)
array_norm=array_reshape/255
print(array_norm.shape)
# Out:
# (1, 100, 100, 3)

# %%
label=["mask_weared_incorrect","with_mask","without_mask"]

# %%
a=model.predict(array_norm)
a
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# array([[9.1755816e-19, 9.9936575e-01, 6.3429627e-04]], dtype=float32)

# %%
b=np.argmax(a)
label[b]
# Out:
# 'with_mask'

# %%
model.save("mask_vedio.h5")#to save the model
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
#model=load_model("mask_vedio.h5")

# %%
capture=cv2.VideoCapture(0)
while True:
    ret,frame=capture.read()
    if ret:
        array_resize=cv2.resize(frame,(100,100))
        array_reshape=array_resize.reshape(1,100,100,3)
        array_norm=array_reshape/255
        a=model.predict(array_norm)
        b=np.argmax(a)
        label=["mask_weared_incorrect","WithMask","WithoutMask"]
        print(label[b])
        cv2.putText(frame,label[b],(50,50),cv2.FONT_HERSHEY_SIMPLEX,0.5,(0,255,0),2)
        cv2.imshow("With or Without Mask Frame",frame)
        if cv2.waitKey(1)& 0xFF==ord("q"):
            break
capture.release()
cv2.destroyAllWindows()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# mask_weared_incorrect
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# mask_weared_incorrect
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# mask_weared_incorrect
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# mask_weared_incorrect
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# mask_weared_incorrect
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# mask_weared_incorrect
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# WithMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# WithMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# WithMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# WithMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# WithMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# WithMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# WithMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# WithMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# WithMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# WithMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# WithMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# WithMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# WithMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# mask_weared_incorrect
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# mask_weared_incorrect
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# mask_weared_incorrect
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# mask_weared_incorrect
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# mask_weared_incorrect
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# mask_weared_incorrect
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# mask_weared_incorrect
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# mask_weared_incorrect
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# mask_weared_incorrect
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# mask_weared_incorrect
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# mask_weared_incorrect
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# mask_weared_incorrect
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# mask_weared_incorrect
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# WithoutMask
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# WithoutMask
